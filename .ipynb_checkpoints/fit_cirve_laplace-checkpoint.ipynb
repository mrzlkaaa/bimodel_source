# %%
import numpy as np
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt

# %%
sys.path.insert(0, os.path.join(
    os.path.abspath(""),
    "core")
)

# %%
from core import preprocessing
from core import fit
from core import config
cfg = config()

# %%
df_init_cos = pd.read_excel("excels/merged_for_angular_cos.xlsx", index_col=[0])

# %%
df_pr_cos, width_cos,\
weights_cos, egroups_cos  = preprocessing.Preprocessor(df_init_cos, "aver", dud=["l", "r"])\
    .angular_data(cos=True, zero_centered=True, mirror=False)

# %%
df_pr_cos
# Out:
#         aver     1.000     2.000     3.000     4.000     5.000     6.000  \
# 0   0.065834  0.013352  0.012929  0.010054  0.008250  0.007400  0.007942
# 1   0.097499  0.014913  0.015530  0.010293  0.009425  0.008325  0.007570
# 2   0.129165  0.015670  0.015343  0.010906  0.009049  0.008764  0.007871
# 3   0.160835  0.016384  0.015670  0.012030  0.010581  0.008854  0.008302
# 4   0.192500  0.017773  0.017209  0.013003  0.010641  0.010110  0.008444
# 5   0.224165  0.018194  0.017684  0.013703  0.011633  0.011524  0.010873
# 6   0.255835  0.019495  0.018314  0.014338  0.011906  0.011238  0.010541
# 7   0.287500  0.020809  0.019230  0.014773  0.012498  0.010741  0.009920
# 8   0.319165  0.021942  0.020020  0.016931  0.015777  0.011886  0.010683
# 9   0.350835  0.023109  0.021126  0.018319  0.015205  0.013943  0.011802
# 10  0.382500  0.023883  0.022706  0.019349  0.015643  0.014349  0.013877
# 11  0.414165  0.024915  0.023634  0.019198  0.016868  0.015543  0.012609
# 12  0.445835  0.027380  0.024562  0.022165  0.018314  0.016118  0.013609
# 13  0.477500  0.027395  0.026584  0.022127  0.019877  0.016955  0.014970
# 14  0.509165  0.029023  0.027004  0.023900  0.020179  0.018198  0.017499
# 15  0.540835  0.030438  0.027598  0.024986  0.021407  0.020580  0.016998
# 16  0.572500  0.031049  0.028714  0.027403  0.023060  0.019161  0.017143
# 17  0.604165  0.033440  0.031006  0.028091  0.025856  0.023972  0.019025
# 18  0.635835  0.034551  0.031565  0.030675  0.027844  0.025376  0.025491
# 19  0.667500  0.036086  0.033780  0.033831  0.029932  0.026678  0.027703
# 20  0.699165  0.038487  0.036631  0.034671  0.032422  0.031043  0.027168
# 21  0.730835  0.040503  0.038822  0.040729  0.036800  0.034272  0.031084
# 22  0.762500  0.043577  0.041793  0.042193  0.039241  0.036986  0.037811
# 23  0.794165  0.044690  0.043897  0.045390  0.043587  0.041984  0.041326
# 24  0.825835  0.048446  0.050240  0.050613  0.050320  0.049138  0.049837
# 25  0.857500  0.051960  0.051651  0.057341  0.060483  0.060532  0.060916
# 26  0.889165  0.054698  0.058628  0.064928  0.069520  0.072237  0.070988
# 27  0.920835  0.060325  0.066173  0.075554  0.084406  0.088012  0.091654
# 28  0.952500  0.065428  0.074740  0.091456  0.107001  0.117371  0.128955
# 29  0.984165  0.072088  0.087217  0.111053  0.142277  0.168710  0.187386
#
#        7.000     8.000     9.000    10.000    11.000    12.000    13.000  \
# 0   0.008310  0.008768  0.009578  0.006300  0.006003  0.009166  0.006806
drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_cos)):
    axs[i].scatter(df_pr_cos["aver"], y_f_lap_cos[i], label=f"laplace - E = {cols[i]}")
    axs[i].scatter(df_pr_cos["aver"], y_f_gauss_cos[i], label=f"gauss - E = {cols[i]}")
    axs[i].scatter(df_pr_cos["aver"], df_pr_cos.loc[:, cols[i]], label=f"origin - E = {cols[i]}")
    axs[i].legend()

# %%
coefs_lap_cos, y_f_lap_cos.sum(axis=1)
# Out:
# ([[0.011734878328948564, -0.5667380107125088, 0.22685339167007876, '1.000'],
#   [0.008905776112364228, -0.46208171108343066, 0.18514814480347913, '2.000'],
#   [0.03333333373994144, 19058766.93324302, 0.13104432084172576, '3.000'],
#   [0.03333333381835421, 12626037.579050424, 0.10615110122798435, '4.000'],
#   [0.0005696448065293188, -0.17789088173540385, 0.08157241643056845, '5.000'],
#   [0.00020821184925716012, -0.14745719626396017, 0.06180089922709997, '6.000'],
#   [0.00012471967098911109, -0.13607292945353844, 0.04717737804305674, '7.000'],
#   [9.974164292591465e-05, -0.131831569775839, 0.03780313154813841, '8.000'],
#   [0.00035386551163407585,
#    -0.16219250165643365,
#    0.032293437522022676,
#    '9.000'],
#   [0.0003117123489552211, -0.15785193141792864, 0.02812261199975313, '10.000'],
#   [0.00019434850896421588,
#    -0.14502335902380215,
#    0.023538588177559074,
#    '11.000'],
#   [0.00021017265894600115,
#    -0.1473102784088538,
#    0.016644581122357352,
#    '12.000'],
#   [0.0007971605565965132, -0.1907352465328087, 0.011853290639356253, '13.000'],
#   [0.0010246078266403918,
#    -0.1997936259688186,
#    0.009996706746820029,
#    '14.000']],
#  array([0.99668844, 0.98649919, 0.99999998, 0.99999997, 0.87871468,
#         0.85165971, 0.83052103, 0.81515458, 0.85897665, 0.87275482,
#         0.87616211, 0.86465749, 0.90122056, 0.95508558]))

# %%
to_export = dict()
for i in range(len(y_f_lap_cos)):
    to_export[coefs_lap_cos[i][-1]] = y_f_lap_cos[i]

# %%
pd.DataFrame(data=to_export).to_excel("fitted_angular_cos.xlsx")

# %% [markdown]
# ## JUST TEST
# ### merged_for_angular_cos_norm.xlsx normilized by width of group in degrees

# %%
df_init_cos_norm = pd.read_excel("excels/merged_for_angular_cos_norm.xlsx", index_col=[0])

# %%
df_pr_cos_norm, width_cos_norm,\
weights_cos_norm, egroups_cos_norm  = preprocessing.Preprocessor(df_init_cos_norm, "aver", dud=["l", "r"])\
    .angular_data(cos=True)

# %%
df_pr_cos_norm.to_excel("df_to_fit_cos_norm.xlsx")

# %%
f_l_norm = fit.Fit(df_pr_cos_norm,  cfg["fit"], "laplace")

# %%
coefs_lap_cos_norm, y_f_lap_cos_norm = f_l_norm.df_fit("aver", width=0.95, weights=weights_cos_norm)

# %%
coefs_lap_cos_norm
# Out:
# [[0.16804293340501544, 0.19457583304638368, 0.198630174945759, '1.000'],
#  [0.2124817607467848, 0.15084599725558787, 0.168689261852191, '2.000'],
#  [0.28388149554923153, 0.11587778407465403, 0.12824463328129515, '3.000'],
#  [0.39036495282671607, 0.08819190336422322, 0.11102768071269033, '4.000'],
#  [0.4915639731329204, 0.07345311690095774, 0.08930961165021585, '5.000'],
#  [0.5652404944008932, 0.06667726091072709, 0.0700563173009695, '6.000'],
#  [0.6044967354524124, 0.06334120243227885, 0.05388948739479878, '7.000'],
#  [0.6092636817504051, 0.06300347277723906, 0.043065010541881776, '8.000'],
#  [0.5066676013259982, 0.07255173298275466, 0.0357586422038139, '9.000'],
#  [0.4864316946613731, 0.07667085415245159, 0.031614819299325275, '10.000'],
#  [0.5101171034673564, 0.07503788853739415, 0.02713697213658756, '11.000'],
#  [0.4875829812542997, 0.0778487168102926, 0.018929494102901675, '12.000'],
#  [0.3487780842003084, 0.1047036663607125, 0.012748125177840297, '13.000'],
#  [0.30259250962789835, 0.12396866344616338, 0.010899769399729807, '14.000']]

# %%
fig, axs = plt.subplots(len(y_f_lap_cos_norm), 1, figsize=(7,50))
cols = df_pr_cos_norm.drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_cos_norm)):
    axs[i].scatter(df_pr_cos_norm["aver"], y_f_lap_cos_norm[i], label="laplace_norm")
#     axs[i].scatter(df_pr_cos["aver"], y_f_lap_cos[i], label="laplace") # not mirrored & zero centered
    axs[i].scatter(df_pr_cos_norm["aver"], df_pr_cos_norm.loc[:, cols[i]], label="origin")
    axs[i].legend()

# %%
to_export = dict()
for i in range(len(y_f_lap_cos_norm)):
    to_export[coefs_lap_cos_norm[i][-1]] = y_f_lap_cos_norm[i]

# %%
pd.DataFrame(data=to_export).to_excel("fitted_angular_cos_norm.xlsx")

# %% [markdown]
# ### Try to fit 30 energy and 30 angular groups

# %%
df_init_cos_30en = pd.read_excel("excels/merged_for_angular_cos_30en.xlsx", index_col=[0])
df_init_cos_30en
# Out:
#         aver      0.750       1.250       1.750       2.250       2.750  \
# 0   0.065834  184160000   300210000   393440000   394570000   321160000
# 1   0.097499  203870000   328010000   422680000   445610000   349890000
# 2   0.129165  216600000   347650000   451760000   447570000   368570000
# 3   0.160835  228240000   367060000   473270000   472970000   409010000
# 4   0.192500  245200000   397150000   498730000   507570000   424370000
# 5   0.224165  263120000   412000000   527640000   533230000   451730000
# 6   0.255835  278690000   444770000   553370000   555770000   497450000
# 7   0.287500  291770000   464620000   573730000   582030000   505500000
# 8   0.319165  312230000   493270000   598180000   620430000   554150000
# 9   0.350835  321800000   510840000   623200000   664760000   592720000
# 10  0.382500  343090000   534190000   667500000   681220000   628200000
# 11  0.414165  358930000   550450000   690010000   705170000   663860000
# 12  0.445835  379880000   578180000   724980000   731330000   708170000
# 13  0.477500  395520000   599310000   759900000   795450000   744990000
# 14  0.509165  421670000   634450000   784100000   822290000   782710000
# 15  0.540835  432830000   665760000   824210000   856410000   819150000
# 16  0.572500  449170000   687100000   868440000   907750000   897290000
# 17  0.604165  475790000   721320000   920780000   942150000   940970000
# 18  0.635835  504500000   760490000   947750000  1015000000   994510000
# 19  0.667500  525500000   793260000  1009300000  1082000000  1071400000
# 25           0           0           0           0           0           0
# 26           0           0           0           0           0           0
# 27           0           0           0           0           0           0
# 28           0           0           0           0           0           0
# 29           0           0           0           0           0           0
#
#       13.250_2   13.750_2   14.250_2
# 0   1030000000  406220000  375150000
# 1            0          0          0
# 2            0          0          0
# 3            0          0          0
# 4            0          0          0
# 5            0          0          0
# 6            0          0          0
# 7            0          0          0
# 8            0          0          0
# 9            0          0          0
# 10           0          0          0
# 11           0          0          0
# 12           0          0          0
# 13           0          0          0
# 14           0          0          0
# 15           0          0          0
# 16           0          0          0
# 17           0          0          0
# 18           0          0          0
# 19           0          0          0
# 20           0          0          0
# 21           0          0          0
# 22           0          0          0
# 23           0          0          0
# 24           0          0          0
# 25           0          0          0
# 26           0          0          0
# 27           0          0          0
# 28           0          0          0
# 29           0          0          0
#
# [30 rows x 85 columns]

# %%
df_pr_cos_30en, width_cos_30en,\
weights_cos_30en, egroups_cos_30en = preprocessing.Preprocessor(df_init_cos_30en, "aver")\
    .angular_data(cos=True, mirror=True)

# %%
width_cos_30en
# Out:
# 1

# %%
df_pr_cos_30en.to_excel("df_to_fit_30en.xlsx")

# %%
coefs_lap_cos_30en, y_f_lap_cos_30en = fit.Fit(df_pr_cos_30en, cfg["fit"], "laplace")\
    .df_fit("aver", width_cos_30en, weights_cos_30en)

# %%
weights_cos_30en
# Out:
# array([0.11842942, 0.10796625, 0.09949836, 0.08550061, 0.06947573,
#        0.06204481, 0.05549947, 0.05033836, 0.0435435 , 0.0379019 ,
#        0.03281391, 0.02863998, 0.02514449, 0.0222296 , 0.01993831,
#        0.01805568, 0.01675649, 0.01587171, 0.01485248, 0.0137298 ,
#        0.01257965, 0.01096946, 0.00914019, 0.00746179, 0.00634935,
#        0.00539782, 0.00513148, 0.0047394 ])

# %%
fig, axs = plt.subplots(len(y_f_lap_cos_30en),1, figsize=(7, 70))
cols = df_pr_cos_30en.drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_cos_30en)):
    axs[i].scatter(df_pr_cos_30en["aver"], y_f_lap_cos_30en[i], label=f"laplace - {cols[i]}")
    axs[i].scatter(df_pr_cos_30en["aver"], df_pr_cos_30en.loc[:, cols[i]], label=f"origin - {cols[i]}")
    axs[i].legend()

# %%
to_export = dict()
for i in range(len(y_f_lap_cos_30en)):
    to_export[coefs_lap_cos_30en[i][-1]] = y_f_lap_cos_30en[i]

# %%
pd.DataFrame(data=to_export).to_excel("fitted_angular_cos_30en.xlsx")

# %% [markdown]
# ## 150 angular groups, 14 en groups

# %%
df_init_cos_150an = pd.read_excel("excels/merged_for_angular_cos_150ang.xlsx", index_col=[0]).iloc[2:, :]

# %%
df_init_cos_150an
# Out:
#          aver      1.000      2.000      3.000       4.000       5.000  \
# 2    0.065834   48815000   86443000   67291000    62008000    51301000
# 3    0.072166   47565000   86240000   67786000    62123000    57966000
# 4    0.078500   49634000   83412000   66815000    64332000    55990000
# 5    0.084834   50558000   85447000   67409000    63959000    55729000
# 6    0.091166   48821000   86402000   70184000    65118000    58905000
# ..        ...        ...        ...        ...         ...         ...
# 145  0.971500  235170000  493260000  666820000   852290000   962780000
# 146  0.977835  241260000  510940000  688150000   915640000  1043800000
# 147  0.984165  249330000  523480000  739150000   970100000  1113800000
# 148  0.990500  250170000  545510000  772500000  1051800000  1233200000
# 149  0.996835  258360000  565750000  826850000  1131200000  1344500000
#
#           6.000       7.000       8.000       9.000     10.000     11.000  \
# 2      49416000    44074000    47053000    43768000   41672000   32387000
# 3      47818000    44311000    49770000    45136000   35831000   31754000
# 4      48686000    41074000    48577000    44717000   34577000   30607000
# 5      50248000    45049000    47914000    40524000   41318000   31644000
# 6      45090000    44069000    47913000    44207000   33886000   36258000
# ..          ...         ...         ...         ...        ...        ...
# 145   946880000   875830000   813710000   718980000  696620000  678660000
# 146  1043100000   979120000   898160000   810500000  784280000  780660000
# 147  1088300000  1030900000   951920000   835940000  760110000  739620000
# 148  1224700000  1194400000  1079000000   985420000  932720000  880500000
# 149  1332800000  1294000000  1150900000  1028900000  955560000  882930000
#
#         12.000     13.000     14.000
# 2     25722000   17703000    8134500
# 3     28666000   19379000   10264000
# 4     24194000   20127000   10098000
# 5     27106000   22086000    8800100
# 6     25289000   24221000    9751000
# ..         ...        ...        ...
# 145  500560000  320490000  286850000
# 146  578860000  360070000  313580000
# 147  516270000  267690000  203350000
# 148  639320000  338950000  237400000
# 149  622280000  287820000  134880000
#
# [148 rows x 15 columns]

# %%
df_pr_cos_150an, width_cos_150an,\
weights_cos_150an, egroups_cos_150an = preprocessing.Preprocessor(df_init_cos_150an, "aver")\
    .angular_data(cos=True, mirror=False)

# %%
coefs_lap_cos_150an, y_f_lap_cos_150an = fit.Fit(df_pr_cos_150an, cfg["fit"], "laplace")\
    .df_fit("aver", width_cos_150an, weights_cos_150an)

# %%
coefs_lap_cos_150an
# Out:
# [[0.00235245340960108, -0.5654221796199567, 0.22619192736814278, '1.000'],
#  [0.0017577220997095186, -0.45668403312691513, 0.18465978480073608, '2.000'],
#  [0.006756756903381774, 13298048.28138892, 0.1316233303618799, '3.000'],
#  [0.0003546104777981622, -0.2337047881624189, 0.10580969804109559, '4.000'],
#  [0.00010083949080283811, -0.17355691596537834, 0.08146687897054995, '5.000'],
#  [4.5287964077429795e-05, -0.14953328321445317, 0.061659100257762445, '6.000'],
#  [2.2143855179201868e-05, -0.13356572080905324, 0.047392617144309396, '7.000'],
#  [1.7749709648165032e-05, -0.1296470394387704, 0.037967529383743315, '8.000'],
#  [4.596373854383649e-05, -0.1503725222284574, 0.03263981168020219, '9.000'],
#  [6.238399890383542e-05, -0.15789566279826278, 0.028643242326294577, '10.000'],
#  [3.4583211911912806e-05, -0.142403309488176, 0.02365169718823303, '11.000'],
#  [4.38016915606458e-05, -0.14838385705731658, 0.016617643510355117, '12.000'],
#  [0.0001790297912934652, -0.19543742065891812, 0.011776071653192595, '13.000'],
#  [0.00022211607445922566, -0.2036707807639241, 0.009900667313503034, '14.000']]

# %%
fig, axs = plt.subplots(len(y_f_lap_cos_150an),1, figsize=(7, 70))
cols = df_pr_cos_150an.drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_cos_150an)):
    axs[i].scatter(df_pr_cos_150an["aver"], y_f_lap_cos_150an[i], label=f"laplace - {cols[i]} - fit={y_f_lap_cos_150an[i].sum()}")
    axs[i].scatter(df_pr_cos_150an["aver"], df_pr_cos_150an.loc[:, cols[i]], label=f"origin - {cols[i]}")
    axs[i].legend()

# %%
y_f_lap_cos_150an.sum(axis=1)
# Out:
# array([0.99662035, 0.98676311, 0.99999998, 0.9271199 , 0.87451858,
#        0.85618049, 0.8325832 , 0.81242921, 0.84176374, 0.87327084,
#        0.87069398, 0.86548317, 0.91378736, 0.95899604])

# %% [markdown]
# ### Try angular distribution in units of degrees but fluxes devided by sr
# #### Data devided by sr represent CDF

# %%
df_init_deg_sr_CDF = pd.read_excel("excels/merged_for_angular_deg_sr_CDF.xlsx", index_col=[0])

# %%
df_init_deg_sr_CDF
# Out:
#     l   r  aver       1.000        2.000        3.000        4.000  \
# 0   0   8     4  6463800000  14077000000  20372000000  28035000000
# 1   8  16    12  6021600000  12746000000  17272000000  22626000000
# 2  16  24    20  5394900000  10667000000  13479000000  16665000000
# 3  24  32    28  4701800000   8644800000  10175000000  11829000000
# 4  32  40    36  4037600000   7043400000   7864700000   8440600000
# 5  40  48    44  3410400000   5778200000   6109600000   6166100000
# 6  48  56    52  2900200000   4764200000   4857300000   4617800000
# 7  56  64    60  2459000000   3979600000   3836900000   3542900000
# 8  64  72    68  2051100000   3325600000   3060400000   2757000000
# 9  72  80    76  1654300000   2722500000   2327900000   2133400000
#
#          5.000        6.000        7.000        8.000        9.000  \
# 0  33284000000  32950000000  31994000000  28811000000  25945000000
# 1  25673000000  25111000000  23679000000  21835000000  19392000000
# 2  17501000000  16928000000  15570000000  14170000000  13182000000
# 3  11697000000  10817000000   9729200000   8722300000   8637700000
# 4   7773000000   6999200000   6128300000   5415200000   5439400000
# 5   5464200000   4728900000   4045900000   3486200000   3630900000
# 6   3947100000   3349900000   2793400000   2537300000   2524500000
# 7   3033400000   2476500000   2102400000   1956100000   1994600000
# 8   2361500000   1940000000   1697500000   1700900000   1720400000
# 9   1839000000   1503100000   1379100000   1409000000   1434600000
#
#         10.000       11.000       12.000      13.000      14.000
# 0  24391000000  22820000000  16038000000  7667100000  4370800000
# 1  18370000000  17819000000  13049000000  8012800000  6835900000
# 2  13545000000  13289000000  10154000000  7927400000  8213700000
# 3   8945100000   8505200000   6640800000  5714200000  5834900000
# 4   5604800000   4999000000   3906100000  3105000000  2922100000
# 5   3509200000   2899800000   2109900000  1521100000  1325000000
# 6   2386600000   1903300000   1237300000   995530000   916930000
# 7   1911400000   1477600000   1170800000  1054300000   948690000
# 8   1526400000   1267900000   1171700000  1077300000   853330000
# 9   1219300000   1093100000   1015200000   830880000   611830000

# %%
df_pr_deg_sr_CDF, width_deg_sr_CDF,\
weights_deg_sr_CDF, egroups_deg_sr_CDF = preprocessing.Preprocessor(df_init_deg_sr_CDF, "aver")\
    .angular_data(cos=False, mirror=False, sr=True, lg="l", rg="r")

# %%
df_pr_deg_sr_CDF.to_excel("df_to_fit_deg_sr_CDF.xlsx")

# %%
coefs_lap_deg_sr_CDF, y_f_lap_deg_sr_CDF = fit.Fit(df_pr_deg_sr_CDF, cfg["fit"], "laplace")\
    .df_fit("aver", width_deg_sr_CDF, weights_deg_sr_CDF)

# %%
coefs_lap_deg_sr_CDF
# Out:
# [[0.18732331024941057, 56.71832315976201, 0.22144853841418724, '1.000'],
#  [0.218197954478218, 43.90694455980234, 0.18165904736794017, '2.000'],
#  [0.26506959859027973, 33.37702363010718, 0.13135597482533334, '3.000'],
#  [0.31330913960265677, 27.148919630381638, 0.10681515579694455, '4.000'],
#  [0.3612799981539699, 23.011724180521604, 0.08301796789966095, '5.000'],
#  [0.3822232200770715, 21.705635132019896, 0.06298513289350473, '6.000'],
#  [0.4028131525890519, 20.47036678125549, 0.04866532237911746, '7.000'],
#  [0.4015796190616499, 20.517456502020483, 0.03888709671113342, '8.000'],
#  [0.3809157423196334, 21.689131960501403, 0.0333087096306458, '9.000'],
#  [0.36802278696227053, 22.744775160163645, 0.02917127291670215, '10.000'],
#  [0.3758638472548543, 22.43147374567993, 0.024094603648414394, '11.000'],
#  [0.3570965202366533, 23.781986189936227, 0.016901765201204007, '12.000'],
#  [0.27724956410299423, 32.61517344210716, 0.011776716667167609, '13.000'],
#  [0.2392943516763066, 40.36791612503884, 0.009912695648044298, '14.000']]

# %%
fig, axs = plt.subplots(len(y_f_lap_deg_sr_CDF),1, figsize=(7, 70))
cols = df_pr_deg_sr_CDF.drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_deg_sr_CDF)):
    axs[i].scatter(df_pr_deg_sr_CDF["aver"], y_f_lap_deg_sr_CDF[i], label=f"laplace - {cols[i]}")
    axs[i].scatter(df_pr_deg_sr_CDF["aver"], df_pr_deg_sr_CDF.loc[:, cols[i]], label=f"origin - {cols[i]}")
    axs[i].legend()

# %%
y_f_lap_deg_sr_CDF.sum(axis=1)
# Out:
# array([1.00316395, 1.00252382, 1.00286094, 1.0037814 , 1.00202783,
#        1.00534037, 1.00362195, 1.00269425, 1.00120314, 1.01005521,
#        1.01871015, 1.02001169, 1.03047067, 1.03935486])

# %%
to_export = dict()
for i in range(len(y_f_lap_deg_sr_CDF)):
    to_export[coefs_lap_deg_sr_CDF[i][-1]] = y_f_lap_deg_sr_CDF[i]

# %%
pd.DataFrame(data=to_export).to_excel("fitted_angular_deg_sr_CDF.xlsx")

# %% [markdown]
# ####  CDF with 28 en and 30 ang groups

# %%
df_init_deg_sr_CDF_28en = pd.read_excel("excels/merged_for_angular_deg_sr_CDF_28en.xlsx", index_col=[0])

# %%
df_pr_deg_sr_CDF_28en, width_deg_sr_CDF_28en,\
weights_deg_sr_CDF_28en, egroups_deg_sr_CDF_28en = preprocessing.Preprocessor(df_init_deg_sr_CDF_28en, "aver")\
    .angular_data(sr=True, mirror=False, lg="l", rg="r")

# %%
df_pr_deg_sr_CDF_28en.to_excel("df_to_fit_deg_sr_CDF_28en.xlsx")

# %%
coefs_lap_deg_sr_CDF_28en, y_f_lap_deg_sr_CDF_28en = fit.Fit(df_pr_deg_sr_CDF_28en, cfg["fit"], "laplace")\
    .df_fit("aver", width_deg_sr_CDF_28en, weights_deg_sr_CDF_28en)

# %%
coefs_lap_deg_sr_CDF_28en
# Out:
# [[0.06105935299430973, 59.11947083211101, 0.11811259339508805, '0.750'],
#  [0.06366901516760098, 54.667806463925665, 0.10747994707989364, '1.250'],
#  [0.06939107363706228, 47.1972849390789, 0.09888223678302847, '1.750'],
#  [0.07675779981870684, 40.46336549433755, 0.0851348035876572, '2.250'],
#  [0.08468358268073736, 35.23371324488647, 0.06959550615942742, '2.750'],
#  [0.09338161010238262, 30.994571581711913, 0.062243164267092664, '3.250'],
#  [0.09981135991095605, 28.551324159839524, 0.05567519460570463, '3.750'],
#  [0.1114259743807891, 25.057713550201946, 0.05051504550461388, '4.250'],
#  [0.11885960266221338, 23.251625096211374, 0.043698352078322594, '4.750'],
#  [0.12362364340026334, 22.252313882970878, 0.038093990690292595, '5.250'],
#  [0.12693844948754995, 21.639613478168535, 0.03297577241426935, '5.750'],
#  [0.13151155730673297, 20.840388388787666, 0.02878981584989569, '6.250'],
#  [0.13569070094760566, 20.08377014054369, 0.025252734582144228, '6.750'],
#  [0.1367611171244554, 19.9251024136003, 0.022305653352289966, '7.250'],
#  [0.13561875028984177, 20.1549721407347, 0.01994917548775456, '7.750'],
#  [0.13397466880227785, 20.342930031035724, 0.018076141910351357, '8.250'],
#  [0.13143110742009334, 20.69969373157351, 0.01676326516651576, '8.750'],
#  [0.1254681705203358, 21.899000183990125, 0.01594586471501908, '9.250'],
#  [0.12742226734476397, 21.506218110144005, 0.014897938303973011, '9.750'],
#  [0.12644948044544757, 21.80524887048354, 0.01377125933857272, '10.250'],
#  [0.12582821249137463, 22.146535175829662, 0.012600969754202919, '10.750'],
#  [0.1319610075482137, 20.954174915322675, 0.010994606479321418, '11.250'],
#  [0.13059904501488112, 21.19303540157883, 0.009150578510043689, '11.750'],
#  [0.11387739021230031, 24.856630984573844, 0.007464781611498479, '12.250'],
#  [0.11312427834000112, 25.030907784497273, 0.006355104982949106, '12.750'],
#  [0.07347416582369398, 45.139080142039944, 0.005371976366026984, '13.250'],
#  [0.0753417751009892, 43.74152405945251, 0.005128625113715154, '13.750'],
#  [0.07853206700398073, 41.44927566105581, 0.004774901910335476, '14.250']]

# %%
fig, axs = plt.subplots(len(y_f_lap_deg_sr_CDF_28en),1, figsize=(7, 70))
cols = df_pr_deg_sr_CDF_28en.drop(["aver"], axis=1).columns
for i in range(len(y_f_lap_deg_sr_CDF_28en)):
    axs[i].scatter(df_pr_deg_sr_CDF_28en["aver"], y_f_lap_deg_sr_CDF_28en[i], label=f"laplace - {cols[i]}")
    axs[i].scatter(df_pr_deg_sr_CDF_28en["aver"], df_pr_deg_sr_CDF_28en.loc[:, cols[i]], label=f"origin - {cols[i]}")
    axs[i].legend()

# %%
to_export = dict()
for i in range(len(y_f_lap_deg_sr_CDF_28en)):
    to_export[coefs_lap_deg_sr_CDF_28en[i][-1]] = y_f_lap_deg_sr_CDF_28en[i]

# %%
pd.DataFrame(data=to_export).to_excel("fitted_angular_deg_sr_CDF_28en.xlsx")
